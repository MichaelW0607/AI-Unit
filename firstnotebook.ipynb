# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Bar Graph

# %%
bar_labels = ['A','B','C','D']
bar_heights = [4, 6, 7, 10]

plt.bar(bar_labels, bar_heights)
plt.show()

# %% [markdown]
# # Scatter Graph

# %%
x = [1,2,3,4,5] 
y = [6,7,8,9,10]
plt.scatter(x,y) 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
